# %%
from api_key import *
import numpy as np
import pandas as pd
import json
import os
import time
import networkx as nx
import scipy.stats as stats
import matplotlib.pyplot as plt 
# %matplotlib inline
import echonest.remix.audio as audio
from pyechonest import artist 
from IPython.display import Audio

# %%
from pyechonest import config
#config.ECHO_NEST_API_KEY = api_key_1
config.ECHO_NEST_API_KEY = api_key_2
#config.ECHO_NEST_API_KEY = api_key_3

# %%
remix_list = ['Adele', u'Emeli Sande', u'Bruno Mars', u'Jason Der\xfclo', 'Justin Bieber']

# %%
songs = ['Adele_-_Hello.mp3',
'Emeli_Sandé_-_My_Kind_Of_Love_(RedOne_and_Alex_P_Remix).mp3',
'Bruno_Mars___Just_The_Way_You_Are___Lyrics_On_Screen_HQ_HD_NEW_SINGLE_2010.mp3',
'Jason_Derulo_-_Want_To_Want_Me_(Official_Video).mp3',
'Justin_Bieber_-_What_Do_You_Mean.mp3']
output = ['songs/test1.mp3', 'songs/test2.mp3', 'songs/test3.mp3', 'songs/test4.mp3', 'songs/test5.mp3']

# %%
audiofile0 = audio.LocalAudioFile('songs/'+songs[0])
bars = audiofile0.analysis.bars
# Out:
# ['en-ffmpeg', '-i', 'songs/Adele_-_Hello.mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpaUHCyN.wav']
# Computed MD5 of file is 0ee23f5a5d6395c95a47dccb88b075ef
# Probing for existing analysis

# %%
out0 = audio.getpieces(audiofile0, bars[20:25])
out0.encode(output[0])
Audio(output[0])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmp035Qrq.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test1.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmp035Qrq.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audiofile1 = audio.LocalAudioFile('songs/'+songs[1])
bars = audiofile1.analysis.bars
# Out:
# ['en-ffmpeg', '-i', 'songs/Emeli_Sande\xcc\x81_-_My_Kind_Of_Love_(RedOne_and_Alex_P_Remix).mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpmWs8Mf.wav']
# Computed MD5 of file is f58b62ea8fc858689d5d00788912ab1f
# Probing for existing analysis

# %%
out1 = audio.getpieces(audiofile1, bars[30:35])
out1.encode(output[1])
Audio(output[1])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpUFvsTq.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test2.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpUFvsTq.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audiofile2 = audio.LocalAudioFile('songs/'+songs[2])
bars = audiofile2.analysis.bars
# Out:
# ['en-ffmpeg', '-i', 'songs/Bruno_Mars___Just_The_Way_You_Are___Lyrics_On_Screen_HQ_HD_NEW_SINGLE_2010.mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpcvKWEx.wav']
# Computed MD5 of file is db9bfd08156a33fdf85938972d7b17b2
# Probing for existing analysis

# %%
out2 = audio.getpieces(audiofile2, bars[50:55])
out2.encode(output[2])
Audio(output[2])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpGxNnvF.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test3.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpGxNnvF.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audiofile3 = audio.LocalAudioFile('songs/'+songs[3])
bars = audiofile3.analysis.bars
len(bars)
# Out:
# ['en-ffmpeg', '-i', 'songs/Jason_Derulo_-_Want_To_Want_Me_(Official_Video).mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpHU03zz.wav']
# Computed MD5 of file is bdf325673cfb94fe00c21fbf3a11722a
# Probing for existing analysis
# 107

# %%
out3 = audio.getpieces(audiofile3, bars[81:86])
out3.encode(output[3])
Audio(output[3])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpbP_9xx.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test4.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpbP_9xx.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audiofile4 = audio.LocalAudioFile('songs/'+songs[4])
bars = audiofile4.analysis.bars
len(bars)
# Out:
# ['en-ffmpeg', '-i', 'songs/Justin_Bieber_-_What_Do_You_Mean.mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpiC5Hy5.wav']
# Computed MD5 of file is f02b0f977adb9fc57bd4c6043434f7cd
# Probing for existing analysis
# 148

# %%
bars[147]
# Out:
# AudioQuantum(kind='bar', start=282.092510, duration=1.915780, confidence=0.345000)

# %%
out4 = audio.getpieces(audiofile4, bars[130:135])
out4.encode(output[4])
Audio(output[4])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpCvv4A7.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test5.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpCvv4A7.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
out = out0+out1+out2+out3+out4

# %%
out.encode('songs/test6.mp3')
Audio('songs/test6.mp3')
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpmqmRu6.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'songs/test6.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpmqmRu6.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%bash
# cd songs
# ls
# Out:
# Adele_-_Hello.mp3
# Bruno_Mars___Just_The_Way_You_Are___Lyrics_On_Screen_HQ_HD_NEW_SINGLE_2010.mp3
# Emeli_Sandé_-_My_Kind_Of_Love_(RedOne_and_Alex_P_Remix).mp3
# James_Blunt_-_Youre_Beautiful.mp3
# Jason_Derulo_-_Want_To_Want_Me_(Official_Video).mp3
# Jason_Mraz_-_Im_Yours.mp3
# Justin_Bieber_-_What_Do_You_Mean.mp3
# Maroon_5_-_Sugar.mp3
# OneRepublic_-_Counting_Stars.mp3
# test1.mp3
# test2.mp3
# test3.mp3
# test4.mp3
# test5.mp3
# test6.mp3

# %%
new_song = ['Maroon_5_-_Sugar.mp3', 
           'Jason_Mraz_-_Im_Yours.mp3',
           'James_Blunt_-_Youre_Beautiful.mp3',
           'OneRepublic_-_Counting_Stars.mp3']

# %%
new_output = ['Maroon_5','Jason_Mraz','James_Blunt','OneRepubli']

# %%
audiofile0 = audio.LocalAudioFile('songs/'+new_song[0])
bars = audiofile0.analysis.bars
len(bars)
# Out:
# ['en-ffmpeg', '-i', 'songs/Maroon_5_-_Sugar.mp3', '-y', '-ac', '2', '-ar', '44100', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpVsEw8G.wav']
# Computed MD5 of file is cab85e9534b405f15ed669264fd6bb51
# Probing for existing analysis
# Analysis not found. Uploading...
# 146

# %%
out0 = audio.getpieces(audiofile0, bars[130:135])
out0.encode(new_output[0])
Audio(new_output[0])
# Out:
# ['en-ffmpeg', '-i', '/var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpOwrk8b.wav', '-y', '-ab', '128k', '-ac', '2', '-ar', '44100', 'Maroon_5.mp3']
# Deleting: /var/folders/n0/h_w4nr5975937v38p5sym7c00000gn/T/tmpOwrk8b.wav
#                 <audio controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
